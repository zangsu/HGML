# %%
from tensorflow import keras
(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()

# %%
from sklearn.model_selection import train_test_split
train_scaled = train_input / 255.0
test_scaled = test_input/ 255
train_scaled = train_scaled.reshape(-1, 28*28)
train_scaled, val_scaled , train_target, val_target= train_test_split(train_scaled, train_target, test_size = 0.2, random_state =42)

# %%
from tensorflow.keras import layers
model = keras.Sequential()
model.add(layers.Dense(100, activation= 'sigmoid', input_shape = (28*28, )))
model.add(layers.Dense(10, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 100)               78500
#
#  dense_3 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = 'sparse_categorical_crossentropy', metrics = 'acc')
model.fit(train_scaled, train_target, epochs = 5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 6s 2ms/step - loss: 0.5634 - acc: 0.8086
# Epoch 2/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.4055 - acc: 0.8546
# Epoch 3/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3704 - acc: 0.8654
# Epoch 4/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3486 - acc: 0.8740
# Epoch 5/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3324 - acc: 0.8788

# %%
#flatten
model = keras.Sequential()
model.add(layers.Flatten(input_shape = (28, 28)))
model.add(layers.Dense(100, activation = 'relu'))
model.add(layers.Dense(10, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense_4 (Dense)             (None, 100)               78500
#
#  dense_5 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()
train_scaled = train_input / 255.0
train_scaled, val_scaled, train_target, val_target = train_test_split(train_scaled, train_target, test_size = 0.2, random_state = 42)

# %%
model.compile(loss = 'sparse_categorical_crossentropy', metrics = 'acc')
model.fit(train_scaled, train_target, epochs = 5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.5311 - acc: 0.8126
# Epoch 2/5
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.3945 - acc: 0.8587
# Epoch 3/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3564 - acc: 0.8729
# Epoch 4/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3345 - acc: 0.8809
# Epoch 5/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3204 - acc: 0.8851

# %%
model.evaluate(val_scaled, val_target)
# Out:
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3688 - acc: 0.8748
# [0.3687543272972107, 0.874750018119812]

# %%
model = keras.Sequential()
model.add(layers.Flatten(input_shape = (28, 28)))
model.add(layers.Dense(100, activation = 'relu'))
model.add(layers.Dense(10, activation = 'softmax'))

# %%
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = 'acc')
model.fit(train_scaled, train_target, epochs = 5)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 4s 2ms/step - loss: 0.5271 - acc: 0.8167
# Epoch 2/5
# 1500/1500 [==============================] - 3s 2ms/step - loss: 0.3934 - acc: 0.8600
# Epoch 3/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3547 - acc: 0.8714
# Epoch 4/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3288 - acc: 0.8808
# Epoch 5/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3071 - acc: 0.8881

# %%
model.evaluate(val_scaled, val_target)
# Out:
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3313 - acc: 0.8802
# [0.3312947452068329, 0.8801666498184204]
